# %% [markdown]
# <a href="https://colab.research.google.com/github/GeerbaniShashi/Sololearn_Python_intermediate/blob/main/Exceptions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = 7
num2 = 0
# print(num1 / num2)
# Creates a ZeroDivisionError: division by zero

# %%
try:
  num1 = 7
  num2 = 0
  print(num1 / num2)
  print("Done Calculation")
except ZeroDivisionError:
  print("An error occurred")
  print("due to zero division")
# Out:
# An error occurred
# due to zero division

# %%
try:
  variable = 10
  print (10 / 2)
except ZeroDivisionError:
  print("Error")
print("Finished")
# Out:
# 5.0
# Finished

# %%
try:
  variable = 10
  print(variable + "hello")
  print(variable / 2)
except ZeroDivisionError:
  print("Divided by zero")
except (ValueError, TypeError):
  print("Error occurred")
# Out:
# Error occurred

# %%
try:
  meaning = 42
  print(meaning / 0)
  print("the meaning of life")
except (ValueError, TypeError):
  print("ValueError or TypeError occurred")
except ZeroDivisionError:
  print("Divided by zero")
# Out:
# Divided by zero

# %%
try:
  word = "spam"
  print(word / 0)
except:
  print("An error occurred")
# Out:
# An error occurred

# %%
try:
  num1 = input(":")
  num2 = input(":")
  print(float(num1) / float(num2))
except:
  print("Invalid input")
# Out:
# :5
# :6
# 0.8333333333333334

# %%
try:
  print("Hello")
  print(1 / 0)
except ZeroDivisionError:
  print("Divided by zero")
finally:
  print("This code will run no matter what")
# Out:
# Hello
# Divided by zero
# This code will run no matter what

# %%
try:
  print(1)
except:
  print(2)
finally:
  print(3)
# Out:
# 1
# 3

# %%
try:
  print(1)
except ZeroDivisionError:
  print(2)
else:
  print(3)

try:
  print(1/0)
except ZeroDivisionError:
  print(4)
else:
  print(5)
# Out:
# 1
# 3
# 4

# %%
try:
  print(1)
  print(1 + "1" == 2)
  print(2)
except TypeError:
  print(3)
else:
  print(4)
# Out:
# 1
# 3

# %%
num = 102
#if num > 100:
#  raise ValueError

#Gives an error

# %%
#try:
#  print(1 / 0)
#except ZeroDivisionError:
#  raise ValueError

# Raises error

# %%
name = "123"
#raise NameError("Invalid name!")

# %%
num = input(":")
if float(num) < 0:
 raise ValueError("Negative!")
# Out:
# :1

# %%
try:
  print(1)
  print(20 / 0)
  print(2)
except ZeroDivisionError:
  print(3)
finally:
  print(4)
# Out:
# 1
# 3
# 4

# %%
num = input()
try:
   x = int(num)
except:
   print("Wrong Input")
# Out:
# shashi
# Wrong Input

# %%
x = 3
try:
  x+="2"
except:
  x+=2
else:
  x+=4
finally:
  print(x)
# Out:
# 5

# %%
try:
  txt = "Bold"
  print(txt[4])
except:
  print("None")
# Out:
# None

# %%
x = 0
try:
  x+=1
  raise ValueError
except NameError:
  x+=1
except ValueError:
  x+=1
else:
  x+=1
finally:
  x+=1
print(x)
# Out:
# 3
